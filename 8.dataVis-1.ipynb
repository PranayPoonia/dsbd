# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df["age"] = df["age"].fillna(df["age"].mean())

# %%
newdf=df.dropna()
newdf=df.drop(['pclass', 'sibsp', 'parch', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone'], axis=1)
newdf
# Out:
#      survived     sex        age     fare
# 0           0    male  22.000000   7.2500
# 1           1  female  38.000000  71.2833
# 2           1  female  26.000000   7.9250
# 3           1  female  35.000000  53.1000
# 4           0    male  35.000000   8.0500
# ..        ...     ...        ...      ...
# 886         0    male  27.000000  13.0000
# 887         1  female  19.000000  30.0000
# 888         0  female  29.699118  23.4500
# 889         1    male  26.000000  30.0000
# 890         0    male  32.000000   7.7500
#
# [891 rows x 4 columns]

# %%
newdf.count()
# Out:
# survived    891
# sex         891
# age         891
# fare        891
# dtype: int64

# %%
sns.histplot(newdf["fare"], bins=8)
# Out:
# <AxesSubplot: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data=newdf, x='fare', hue='survived', bins=10);
